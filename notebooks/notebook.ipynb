# %%
import os
import random

# %%
from squiggle_detector import *
from collections import OrderedDict
# Out:
# /anaconda3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# # Function

# %%
def squiggle_detect(
    # File I/O parameters
    filename,
    species,
    helper_files_path,
    templates_path,
    csvs_dir,
    
    # Spectrogram parameters
    sample_rate,
    samples_per_seg,
    overlap_percent,
    low_frequency_thresh = None,
    high_frequency_thresh = None,
    
    # Noise reduction parameters
    median_binarize_multiplier = 9.0,
    small_obj_size = 1000.0,
    binary_closing_size = (5, 5),
    binary_dilation_size = (3, 5),
    
    # Other things
    verbosity = 0,
    audio_or_image = 'audio'
):
    '''
    Squiggle-detect on a spectrogram
    
    Inputs:
        filename (str): the path of the file to squiggle-detect on
        sample_rate (int): sample rate for audio processing
        save_dir (str): 
        species (str): the species of this file
            used to organize results into specices
        cat_num (int): the catalogue number of this file
            unique number identifying the file, used to
            organize results by source file
    
    Results:
        Puts files into the following directory structure:
        
            helper_files_path/
            |---species/
            |   |---cat_num_detections.wav
            |   |---cat_num_noise.wav
            |   |---cat_num_denoised.wav



            templates_path/
            |---species/
            |   |---cat_num1.wav
            |   |---cat_num2.wav
            |   |---...
            |
            |---csvs_dir/
            |   |---species.csv
        
        where species.csv has the format:
            Filename,Duration,LowFreq,HighFreq
            cat_num1.wav,<seconds>,<Hz>,<Hz>
    '''
    
    # Load file
    samples, sample_rate = load_file(
        filename = filename,
        sample_rate = sample_rate)

    # Make spectrogram
    freqs, times, spect = make_spect(
        samples = samples,
        samples_per_seg = samples_per_seg,
        overlap_percent = overlap_percent,
        sample_rate = sample_rate)
    
    if verbosity > 0:
        plotter(spect, upside_down=True, title=f'Initial spectrogram for {filename}', db=True)

    # Remove undesired frequencies
    #low_frequency_thresh = 173
    #high_frequency_thresh = 10033
    #spect, f = spectrogram_bandpass(spect, f, low_frequency_thresh, high_frequency_thresh)
    #if verbosity > 1:
    #    plotter(power_to_db(spect), upside_down=True, title='Frequencies removed')

    ### STEP 1 ###
    # Normalize spectrogram
    normalized_spect = normalize_spect(spect)

    # Binarize by median filtering
    binary_spect = binarize_by_median(normalized_spect, multiplier = median_binarize_multiplier)
    
    # Image processing noise reduction
    desired_steps = OrderedDict({
        'binary_closing':binary_closing_size,
        'binary_dilation':binary_dilation_size,
        'small_objects':small_obj_size
    })
    if verbosity > 1:
        binary_processed = image_processing_dict( 
            spectrogram = binary_spect,
            params = desired_steps,
            plot_func = plotter
        )
    else:
        binary_processed = image_processing_dict( 
            spectrogram = binary_spect,
            params = desired_steps
            #plot_func = plotter
        )

    # Find bounding boxes in processed spect
    bounding_boxes = box_binary(binary_processed, verbose = verbosity)

    # Use bounding boxes to save noise and detections files
    noise_filename = save_noise_and_detections_files(
        binary_spectrogram=binary_processed,
        bounding_boxes=bounding_boxes,
        original_filename=filename,
        samples = samples,
        freqs = freqs,
        times = times,
        sr = sample_rate,
        newdir = helper_files_path,
        subdir = species
    )

    # Noise-reduce the samples
    samples_nr = audacity_noise_reduce(noise_file=noise_filename, audio_samples=samples)
    freqs_nr, times_nr, spect_nr = make_spect(
        samples_nr, samples_per_seg=samples_per_seg, overlap_percent=overlap_percent)
    spect_nr = normalize_spect(spect_nr)
    if verbosity > 1:
        plotter(spect_nr, db=True, title='noise-reduced')

    # Save denoised sound file
    wav_writer(
        samples = samples_nr,
        sample_rate=sample_rate,
        suffix='denoised',
        orig=filename,
        newdir=helper_files_path,
        subdir=species
    )
    
    ## STEP 2 ##
    # If using Audacity noise reduction and binary_spect was not made from 
    # the noise-reduced spectrogram, it will be slightly larger than the 
    # noise-reduced spect. Make them the same size by just selecting the 
    # first part of the binary_spect:
    if spect_nr.shape != binary_spect.shape:
        shape_difference = np.subtract(spect_nr.shape, binary_spect.shape)
        new_dims = np.add(binary_spect.shape, shape_difference)
        # TODO: centering this might work better than just taking the beginning
        binary_spect_to_use = binary_spect[0:new_dims[0], 0:new_dims[1]]
    else:
        binary_spect_to_use = binary_spect

    # Save each extracted segment
    csv_folder = os.path.join(templates_path, csvs_dir)
    try: os.mkdir(csv_folder)
    except: pass
    csv_path = os.path.join(csv_folder, f'{species}.csv')
    
    if audio_or_image == 'audio':
        identify_segments_audio(
            filename = filename,
            samples = samples_nr,
            bounding_boxes = bounding_boxes,
            sample_rate = sample_rate, 
            freqs = freqs_nr,
            times = times_nr,
            basepath = templates_path,
            template_dir = species,
            csv_path = csv_path)

    # Identify segments on spectrogram
    else:
        if verbosity > 0:
            segs = identify_segments(
                spect_nr, binary_spect_to_use, bounding_boxes, plot_func=plotter, margin = 3)#, method='min')
        else:
            segs = identify_segments(
                spect_nr, binary_spect_to_use, bounding_boxes, margin = 3)#, plot_func=plotter, method='min')
        
        return segs

# TODO: add headers to csvs

# %% [markdown]
# # Parameters

# %% [markdown]
# ### Files to use

# %%
import csv
assess_file = 'app/assess.csv'
count = 0
use_files = []
with open(assess_file, 'r') as f:
    reader = csv.reader(f)
    for line in reader:
        if line[1] == 'accept':
            use_files.append(line[0])
len(use_files)
# Out:
# 402

# %% [markdown]
# Had to run this with plt.show() commented out in the plotter function; also ran without most print statements

# %%
helper_files_path = '/Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files'
templates_path = '/Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates'
csvs_dir = 'foreground_csvs'
samples_per_seg = 512
overlap_percent = 0.75
sample_rate = 22050.0
debug=False

for file in use_files[0:10]:
    species = file.split('/')[-2]
    
    squiggle_detect(
        # File I/O parameters
        filename = file,
        species = species,
        helper_files_path = helper_files_path,
        templates_path = templates_path,
        csvs_dir = csvs_dir,

        # Spectrogram parameters
        sample_rate = sample_rate,
        samples_per_seg = samples_per_seg,
        overlap_percent = overlap_percent,
        low_frequency_thresh = None,
        high_frequency_thresh = None,

        # Noise reduction parameters
        median_binarize_multiplier = 9.0,
        small_obj_size = 1000.0,
        binary_closing_size = (5, 5),
        binary_dilation_size = (3, 5),

        # Other things
        verbosity = 2,
        audio_or_image = 'audio'
    )
# Out:
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/325407_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/325407_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/325407_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection6.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection7.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection8.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection9.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection10.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection11.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection12.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/325407_detection13.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/420730_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/420730_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/420730_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection6.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection7.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection8.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection9.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection10.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection11.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection12.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection13.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection14.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection15.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection16.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection17.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection18.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection19.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection20.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection21.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection22.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection23.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection24.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection25.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection26.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection27.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection28.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection29.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection30.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection31.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection32.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection33.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection34.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection35.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection36.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection37.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection38.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection39.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection40.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection41.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection42.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection43.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection44.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection45.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection46.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection47.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection48.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection49.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection50.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection51.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection52.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection53.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection54.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection55.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection56.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection57.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection58.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection59.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection60.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection61.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection62.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection63.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection64.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection65.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection66.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection67.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection68.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection69.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection70.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection71.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection72.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection73.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection74.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection75.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection76.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection77.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection78.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection79.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection80.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection81.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection82.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection83.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection84.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection85.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection86.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection87.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection88.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection89.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection90.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection91.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection92.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection93.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection94.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection95.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection96.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection97.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection98.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection99.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection100.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection101.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection102.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection103.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection104.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection105.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection106.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection107.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection108.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection109.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection110.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection111.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection112.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection113.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection114.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection115.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection116.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection117.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection118.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/420730_detection119.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/100199_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/100199_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/100199_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100199_detection6.wav
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/76682_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/76682_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/76682_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection6.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection7.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection8.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection9.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection10.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection11.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection12.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection13.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection14.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection15.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection16.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection17.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection18.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection19.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection20.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection21.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection22.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection23.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection24.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection25.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection26.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection27.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/76682_detection28.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/59117_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/59117_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/59117_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/59117_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/59117_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/59117_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/59117_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/100200_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/100200_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/100200_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/100200_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/254459_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/254459_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/254459_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection6.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection7.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection8.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection9.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection10.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/254459_detection11.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/13640_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/13640_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/13640_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/13640_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/13640_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/13640_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/13640_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/51470_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/51470_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/51470_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection6.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection7.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection8.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection9.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection10.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection11.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection12.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection13.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection14.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection15.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection16.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection17.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection18.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection19.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection20.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection21.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection22.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection23.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/51470_detection24.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/149490_noise.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/149490_detections.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/helper_files/seiurus-aurocapilla/149490_denoised.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection0.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection1.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection2.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection3.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection4.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection5.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection6.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection7.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection8.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection9.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection10.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection11.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection12.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection13.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection14.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection15.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection16.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection17.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection18.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection19.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection20.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection21.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection22.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection23.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection24.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection25.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection26.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection27.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection28.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection29.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection30.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection31.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection32.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection33.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection34.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection35.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection36.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection37.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection38.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection39.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection40.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection41.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection42.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection43.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection44.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection45.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection46.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection47.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection48.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection49.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection50.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection51.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection52.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection53.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection54.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection55.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection56.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection57.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection58.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection59.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection60.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection61.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection62.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection63.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection64.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection65.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection66.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection67.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection68.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection69.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection70.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection71.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection72.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection73.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection74.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection75.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection76.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection77.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection78.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection79.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection80.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection81.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection82.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection83.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection84.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection85.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection86.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection87.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection88.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection89.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection90.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection91.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection92.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection93.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection94.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection95.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection96.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection97.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection98.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection99.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection100.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection101.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection102.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection103.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection104.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection105.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection106.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection107.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection108.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection109.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection110.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection111.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection112.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection113.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection114.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection115.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection116.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection117.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection118.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection119.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection120.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection121.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection122.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection123.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection124.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection125.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection126.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection127.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection128.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection129.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection130.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection131.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection132.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection133.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection134.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection135.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection136.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection137.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection138.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection139.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection140.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection141.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection142.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection143.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection144.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection145.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection146.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection147.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection148.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection149.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection150.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection151.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection152.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection153.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection154.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection155.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection156.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection157.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection158.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection159.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection160.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection161.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection162.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection163.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection164.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection165.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection166.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection167.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection168.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection169.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection170.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection171.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection172.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection173.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection174.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection175.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection176.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection177.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection178.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection179.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection180.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection181.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection182.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection183.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection184.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection185.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection186.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection187.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection188.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection189.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection190.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection191.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection192.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection193.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection194.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection195.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection196.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection197.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection198.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection199.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection200.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection201.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection202.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection203.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection204.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection205.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection206.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection207.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection208.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection209.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection210.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection211.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection212.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection213.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection214.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection215.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection216.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection217.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection218.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection219.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection220.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection221.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection222.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection223.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection224.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection225.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection226.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection227.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection228.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection229.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection230.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection231.wav
# Saved files to /Users/tessa/Code/detect-towhee/squiggle-detector/detections/templates/seiurus-aurocapilla/149490_detection232.wav

# %% [markdown]
# # Old version

# %% [markdown]
# Used with slightly different module versions

# %% [markdown]
#     try: os.mkdir(base_dir)
#     except FileExistsError:
#         pass
#
#
#
#     for filename in filenames:
#         # Load file
#         samples, sample_rate = load_file(
#             filename = filename,
#             sample_rate = sample_rate)
#
#         # Place to store the results
#         split = filename.split('/')
#         species = split[5]
#         cat_num = os.path.splitext(split[7])[0] #splitext removes the .mp3
#         base_dir_1 = os.path.join(base_dir, species)
#         try: os.mkdir(base_dir_1)
#         except FileExistsError:
#             pass
#         newdir = os.path.join(base_dir_1, cat_num)
#
#         # Make spectrogram
#         freqs, times, spect = make_spect(
#             samples = samples,
#             samples_per_seg = samples_per_seg,
#             overlap_percent = overlap_percent,
#             sample_rate = sample_rate)
#         plotter(spect, upside_down=True, title=f'Initial spectrogram for {filename}', db=True)
#
#         # Remove undesired frequencies
#         #low_frequency_thresh = 173
#         #high_frequency_thresh = 10033
#         #spect, f = spectrogram_bandpass(spect, f, low_frequency_thresh, high_frequency_thresh)
#         if debug:
#             plotter(power_to_db(spect), upside_down=True)
#
#         ### STEP 1 ###
#         # Normalize spectrogram
#         normalized_spect = normalize_spect(spect)
#
#         # Binarize by median filtering
#         median_binarize_multiplier = 9.0
#         binary_spect = binarize_by_median(normalized_spect, multiplier = median_binarize_multiplier)
#
#         # Image processing noise reduction
#         small_obj_size = 1000.0
#         binary_closing_size = (5, 5)
#         binary_dilation_size = (3, 5)
#         desired_steps = OrderedDict({
#             'binary_closing':binary_closing_size,
#             'binary_dilation':binary_dilation_size,
#             'small_objects':small_obj_size
#         })
#         if debug:
#             binary_processed = image_processing_dict(
#                 spectrogram = binary_spect,
#                 params = desired_steps,
#                 plot_func = plotter
#             )
#         else:
#             binary_processed = image_processing_dict(
#                 spectrogram = binary_spect,
#                 params = desired_steps
#                 #plot_func = plotter
#             )
#
#         # Find bounding boxes in processed spect
#         bounding_boxes = box_binary(binary_processed)
#
#         # Use bounding boxes to save a noise file
#         noise_filename = save_noise_file(
#             binary_spectrogram=binary_processed,
#             bounding_boxes=bounding_boxes,
#             original_filename=filename,
#             samples = samples,
#             freqs = freqs,
#             times = times,
#             sr = sample_rate,
#             newdir = newdir,
#             subdir = None
#         )
#
#         # Noise-reduce the samples
#         samples_nr = audacity_noise_reduce(noise_file=noise_filename, audio_samples=samples)
#         freqs_nr, times_nr, spect_nr = make_spect(samples_nr, samples_per_seg=samples_per_seg, overlap_percent=overlap_percent)
#         spect_nr = normalize_spect(spect_nr)
#         if debug:
#             plotter(spect_nr, db=True, title='noise-reduced')
#
#         # Save denoised sound file
#         wav_writer(samples = samples_nr, sample_rate=sample_rate, suffix='denoised', orig=filename, newdir=newdir)
#
#         ## STEP 2 ##
#
#
#         # If using Audacity noise reduction and binary_spect was not made from
#         # the noise-reduced spectrogram, it will be slightly larger than the
#         # noise-reduced spect. Make them the same size by just selecting the
#         # first part of the binary_spect:
#         if spect_nr.shape != binary_spect.shape:
#             shape_difference = np.subtract(spect_nr.shape, binary_spect.shape)
#             new_dims = np.add(binary_spect.shape, shape_difference)
#             # TODO: centering this might work better than just taking the beginning
#             binary_spect_to_use = binary_spect[0:new_dims[0], 0:new_dims[1]]
#         else:
#             binary_spect_to_use = binary_spect
#
#         # Identify segments
#         segs = identify_segments(spect_nr, binary_spect_to_use, bounding_boxes, plot_func=plotter, margin = 3)#, method='min')
#
#         # Save samples
#         for idx, box in enumerate(bounding_boxes):
#             # convert box, which is in terms of numpy array, to sample number and frequency number
#             high_freq, low_freq, start_sample, end_sample = box_to_ft(box, freqs_nr, times, sample_rate) #Note: times_nr results in out of bounds
#
#             # extract those samples from the audio
#             segment_samples = samples_nr[start_sample: end_sample]
#
#             # bandpass filter the samples above and below the box limits
#             filtered_samples = butter_bandpass_filter(segment_samples, low_freq, high_freq, sample_rate)
#
#             # save samples
#             wav_writer(filtered_samples, sample_rate, f'detection{idx}', orig=filename, newdir=newdir, subdir='detections')

# %% [markdown]
# # Example segment plotting

# %% [markdown]
# Within loop:
#
#     # DEFINE segs_dict = {} outside of loop
#
#     # save for later so that we could plot them in different ways if desired
#     segs_dict[filename] = segs
#
#     num_segs = len(segs)
#     num_cols = 3
#     num_rows = int(np.ceil(num_segs/num_cols))
#
#     fig, ax = plt.subplots(num_rows, num_cols, figsize=(10, 15))
#     ordered_axes = []
#     if num_rows == 1:
#         for ax1 in range(ax.shape[0]):
#             ordered_axes.append(ax[ax1])
#     else:
#         for ax1 in range(ax.shape[0]):
#             for ax2 in range(ax.shape[1]):
#                 ordered_axes.append(ax[ax1][ax2])
#     for idx, axis in enumerate(ordered_axes):
#         if idx >= len(segs):
#             break
#         axis.imshow(np.log(cropper(segs[idx])), cmap=plt.get_cmap("gray_r"))
#         axis.set_title(f'segment {idx} (db)')
#         axis.set_aspect(segs[idx].shape[1] / (10*segs[idx].shape[0]))
#     fig.subplots_adjust(hspace=0.5)
#     fig.suptitle(f'segments from {filename}')
#
#
# Outside of loop:
#
#
#     for key in segs_dict.keys():
#         segs = segs_dict[key]
#         num_segs = len(segs)
#         num_cols = 3
#         num_rows = int(np.ceil(num_segs/num_cols))
#
#         fig, ax = plt.subplots(num_rows, num_cols, figsize=(10, 15))
#         ordered_axes = []
#         for ax1 in range(ax.shape[0]):
#             for ax2 in range(ax.shape[1]):
#                 ordered_axes.append(ax[ax1][ax2])
#         for idx, axis in enumerate(ordered_axes):
#             if idx >= len(segs):
#                 break
#             axis.imshow(np.log(cropper(segs[idx])), cmap=plt.get_cmap("gray_r"))
#             axis.set_title(f'segment {idx} (db)')
#             axis.set_aspect(segs[idx].shape[1] / (10*segs[idx].shape[0]))
#         fig.subplots_adjust(hspace=0.5)
#         fig.suptitle(f'segments from {key}')
